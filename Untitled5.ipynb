# %% [markdown]
# <a href="https://colab.research.google.com/github/Vickymaurya1/HTML-CSS-food-delivery/blob/main/Untitled5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Core Pathway imports
import pathway as pw

# Standard library imports
import os
import json
import math
import random
import time
import threading
from datetime import datetime, timedelta
from typing import Optional, Dict, List, Any, Tuple
from dataclasses import dataclass

# Data processing
import numpy as np

# For document processing (RAG)
from pathlib import Path

# HTTP requests (for API testing)
import requests

# Display utilities for Colab
from IPython.display import display, HTML, clear_output
import pandas as pd

from langchain_openai import OpenAIEmbeddings
from langchain_community.vectorstores import Chroma

from langchain_core.prompts import ChatPromptTemplate
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipython-input-1463282821.py in <cell line: 0>()
#       1 # Core Pathway imports
# ----> 2 import pathway as pw
#       3
#       4 # Standard library imports
#       5 import os
#
# ModuleNotFoundError: No module named 'pathway'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
from google.colab import userdata
import os
os.environ["OPENAI_API_KEY"] = userdata.get('OpenAi-Rag')

# %%
from langchain_community.document_loaders import WebBaseLoader, PyPDFLoader

#Load Web Data
web_loader = WebBaseLoader(
    web_paths=["https://www.ni.com/docs/en-US/"]
)
web_docs = web_loader.load()


# Load PDF Data
pdf_path = "/content/Hydraulic pumps.pdf"

pdf_loader = PyPDFLoader(pdf_path)
pdf_docs = pdf_loader.load()

all_docs = web_docs + pdf_docs

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

# %%
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=500,
    chunk_overlap=100
)

chunks = text_splitter.split_documents(all_docs)

print(f"Total chunks after splitting: {len(chunks)}")

# %%
# View one chunk
print(chunks[0].page_content)

# Check metadata
print(chunks[0].metadata)

# %%
from langchain_community.embeddings import HuggingFaceEmbeddings
from langchain_community.vectorstores import Chroma

embedding = HuggingFaceEmbeddings(
    model_name="sentence-transformers/all-MiniLM-L6-v2"
)

vectorstore = Chroma.from_documents(
    documents=chunks,
    embedding=embedding,
    persist_directory="./chroma_db"
)

vectorstore.persist()

# %%
retriever = vectorstore.as_retriever()

# %%
rag_prompt = ChatPromptTemplate.from_template(
    """
    You are a technical assistant designed to answer questions using official
    documentation and technical manuals.

    Use ONLY the provided context extracted from PDF manuals and web
    documentation to answer the question.

    If the answer is not present in the context, clearly say:
    "I don't know based on the provided documents."

    Keep the answer concise, factual, and technical.
    Limit the response to a maximum of three sentences.

    Question: {question}
    Context: {context}
    Answer:
    """
)

# %%
from transformers import pipeline

generator = pipeline(
    "text-generation",
    model="TinyLlama/TinyLlama-1.1B-Chat-v1.0",
    max_new_tokens=100,
    do_sample=False
)

print(generator("Explain what a hydraulic pump is in one sentence.")[0]["generated_text"])
